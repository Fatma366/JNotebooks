# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.colors as mcolors

# %%
data = pd.read_excel("C:/Users/Admin/Desktop/RESULTS 2.0/Biochemical tests, 101, coded.xlsx",header=0)

# %%
cd C:/Users/Admin/Desktop/RESULTS 2.0
# Out:
# C:\Users\Admin\Desktop\RESULTS 2.0

# %%
data = pd.read_excel("Biochemical tests, 101, coded.xlsx",index_col=0)
data3=data.T
data3
# Out:
# Sample ID    001Di (1)  001Di (2a)  001Di (2b)  001Di (2c)  001Di (3)  \
# Methyl Red           0           0           1           1          0
# Citrate              1           1           1           1          1
# Catalase             1           1           1           0          1
# Motility             1           1           1           0          0
# Indole test          0           0           1           0          0
# Urease test          0           0           0           0          0
# Glucose              1           1           1           1          1
# Sucrose              0           1           0           0          0
# Lactose              0           1           0           0          0
# H2S                  0           0           1           0          0
# CO2                  0           0           0           0          0
# Oxidase              1           0           1           1          0
#
# ...

# %%
s = sns.clustermap(data3, figsize=(10, 7), cmap='coolwarm', vmin=0, vmax=1, cbar_pos=(1.1, 0.3, 0.02, 0.5))
