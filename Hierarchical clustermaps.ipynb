# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib.colors as mcolors

# %%
data = pd.read_excel("C:/Users/Admin/Desktop/miniconda docs/fungi_cdd.xlsx",header=0)

# %%
cd C:/Users/Admin/Desktop/miniconda docs
# Out:
# C:\Users\Admin\Desktop\miniconda docs

# %%
data = pd.read_excel("fungi_cdd.xlsx",index_col=0)

# %%
data3=data.T

# %%
data3
# Out:
# Sample ID      001Diii  002Cii  004Aii (3)  004Aii (2)  004Aii (1)  \
# Top colour           1       2           3           3           1
# Bottom colour        3       9           3           3           3
# Appearance           1       3           1           1           1
# Surface              1       1           1           1           1
# Mycellium            1       1           1           1           1
# Form                 1       1           1           1           1
# Elevation            1       2           1           1           1
# Margin               1       2           1           1           1
# Hyphae               1       1           1           1           1
# Spores               0       0           0           0           0
#
# Sample ID      006Aii (1)  006Aii (2)  008Ai (1)  008Ai (2)  008Ai (3)  ...  \
# Top colour              1          11          1          1         12  ...
# ...

# %%
color=["purple","red","blue","chocolate","yellow","green",]

# %%
s=sns.clustermap(data3,figsize=(10,7),cmap=color,vmin=0,vmax=6,cbar_pos=(1.1,0.3,0.02,0.5))

# %%
s.savefig("fungi_cdd.png")
